# %%
import psycopg
import pandas as pd
import numpy as np
import math as m

# %%
conn = psycopg.connect(
    host = "sculptor.stat.cmu.edu", dbname = "hireng",
    user = "hireng", password = "aiVee0Ohs"
)

cur = conn.cursor()
df = pd.read_csv('./HHS_data/2022-09-23-hhs-data.csv')

conn.autocommit = True
df = df.replace({np.nan: None})

# %%
# df["all_adult_hospital_beds_7_day_avg"] = df["all_adult_hospital_beds_7_day_avg"].astype(float)
# df["all_pediatric_inpatient_beds_7_day_avg"] = df["all_pediatric_inpatient_beds_7_day_avg"].astype(float)
# df["all_adult_hospital_inpatient_bed_occupied_7_day_coverage"] = df["all_adult_hospital_inpatient_bed_occupied_7_day_coverage"].astype(float)
# df["all_pediatric_inpatient_bed_occupied_7_day_avg"] = df["all_pediatric_inpatient_bed_occupied_7_day_avg"].astype(float)
# df["total_icu_beds_7_day_avg"] = df["total_icu_beds_7_day_avg"].astype(float)
# df["icu_beds_used_7_day_avg"] = df["icu_beds_used_7_day_avg"].astype(float)
# df["inpatient_beds_used_covid_7_day_avg"] = df["inpatient_beds_used_covid_7_day_avg"].astype(float)
# df["staffed_icu_adult_patients_confirmed_covid_7_day_avg"] = df["staffed_icu_adult_patients_confirmed_covid_7_day_avg"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4996 entries, 0 to 4995
# Columns: 127 entries, hospital_pk to total_staffed_pediatric_icu_beds_7_day_sum
# dtypes: bool(1), int64(39), object(87)
# memory usage: 4.8+ MB

# %%
df2=pd.DataFrame(columns = ["hospital_pk", "collection_week", "all_adult_hospital_beds_7_day_avg", "all_pediatric_inpatient_beds_7_day_avg", "all_adult_hospital_inpatient_bed_occupied_7_day_coverage", "all_pediatric_inpatient_bed_occupied_7_day_avg", "total_icu_beds_7_day_avg", "icu_beds_used_7_day_avg", "inpatient_beds_used_covid_7_day_avg", "staffed_icu_adult_patients_confirmed_covid_7_day_avg"])
n_row=0
df2
# Out:
# Empty DataFrame
# Columns: [hospital_pk, collection_week, all_adult_hospital_beds_7_day_avg, all_pediatric_inpatient_beds_7_day_avg, all_adult_hospital_inpatient_bed_occupied_7_day_coverage, all_pediatric_inpatient_bed_occupied_7_day_avg, total_icu_beds_7_day_avg, icu_beds_used_7_day_avg, inpatient_beds_used_covid_7_day_avg, staffed_icu_adult_patients_confirmed_covid_7_day_avg]
# Index: []

# %%
# a = df.iloc[0, 96]
# print(m.isnan(a))
# print(type(a))
# a = (str(a)).find("(")
# print(a)

# b = df.iloc[1, 96][6:].strip("()").split(" ")[0]
# print(b)
# print(type(b))

# c = float(df.iloc[2, 96][6:].strip("()").split(" ")[0])
# print(c)
# print(type(c))

# if (m.isnan(df.iloc[0, 96])):
#     print("Yes")

d = df.iloc[0, 0]
print(d)
# Out:
# 640001

# %%
with conn.transaction():
    for row in range(df.shape[0]):
        hospital_pk = df.iloc[row, 0]
        state = df.iloc[row, 2]
        hospital_name = df.iloc[row, 4]
        address = df.iloc[row, 5]
        city = df.iloc[row, 6]
        zip = df.iloc[row, 7]
        fips_code = df.iloc[row, 9]
        geocoded_hospital_address = (df.iloc[row, 96])
        if (((geocoded_hospital_address is None))):
            geocoded_hospital_address_1 = None
            geocoded_hospital_address_2 = None
        else:
            geocoded_hospital_address_1 =  float(geocoded_hospital_address[6:].strip("()").split(" ")[0])
            geocoded_hospital_address_2 =  float(geocoded_hospital_address[6:].strip("()").split(" ")[1])
        cur.execute("insert into hospital_innffn (hospital_pk, state, hospital_name, address, city, zip, fips_code, geocoded_hospital_address_1, geocoded_hospital_address_2) values (%s, %s, %s, %s, %s, %s, %s, %s, %s) ON CONFLICT (hospital_pk) DO NOTHING ", (hospital_pk, state, hospital_name, address, city, int(zip), (fips_code), (geocoded_hospital_address_1), (geocoded_hospital_address_2)))
        #address, city, zip, fips_code, geocoded_hospital_address) values (%s, %s, %s, %s, %s, %s, %s, %s)" "ON CONFLICT (hospital_pk) DO NOTHING ", (hospital_pk, state, hospital_name, address, city, zip, fips_code, geocoded_hospital_address))

# %%
df = df.replace({np.nan: None})
missing_values = [-999999,np.nan]
df=pd.read_csv("HHS_data/2022-09-23-hhs-data.csv", na_values=missing_values)

# %%
def if_float(n):
    if (n is np.nan):
        return None
    else:
        return float(n)

# %%
nrow=0
df3=pd.DataFrame(columns=["hospital_pk", "collection_week", "all_adult_hospital_beds_7_day_avg", "all_pediatric_inpatient_beds_7_day_avg", "all_adult_hospital_inpatient_bed_occupied_7_day_coverage", "all_pediatric_inpatient_bed_occupied_7_day_avg", "total_icu_beds_7_day_avg", "icu_beds_used_7_day_avg", "inpatient_beds_used_covid_7_day_avg", "staffed_icu_adult_patients_confirmed_covid_7_day_avg"])
num_rows_inserted_weekly=0
with conn.transaction():
    for row in range(df.shape[0]):
        hospital_pk = df.iloc[row, 0]
        collection_week = df.iloc[row, 1]
        all_adult_hospital_beds_7_day_avg = df.iloc[row, 12]
        all_pediatric_inpatient_beds_7_day_avg = df.iloc[row, 111]
        all_adult_hospital_inpatient_bed_occupied_7_day_coverage = df.iloc[row, 55]
        all_pediatric_inpatient_bed_occupied_7_day_avg = df.iloc[row, 108]
        total_icu_beds_7_day_avg = df.iloc[row, 22]
        icu_beds_used_7_day_avg = df.iloc[row, 24]
        inpatient_beds_used_covid_7_day_avg = df.iloc[row, 16]
        staffed_icu_adult_patients_confirmed_covid_7_day_avg = df.iloc[row, 27]
        try:
            with conn.transaction():
                cur.execute("insert into hospital_we2(hospital_pk, collection_week, all_adult_hospital_beds_7_day_avg, all_pediatric_inpatient_beds_7_day_avg, all_adult_hospital_inpatient_bed_occupied_7_day_coverage, all_pediatric_inpatient_bed_occupied_7_day_avg, total_icu_beds_7_day_avg, icu_beds_used_7_day_avg, inpatient_beds_used_covid_7_day_avg, staffed_icu_adult_patients_confirmed_covid_7_day_avg) " 
                "values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", (hospital_pk, collection_week, if_float(all_adult_hospital_beds_7_day_avg), if_float(all_pediatric_inpatient_beds_7_day_avg), if_float(all_adult_hospital_inpatient_bed_occupied_7_day_coverage), if_float(all_pediatric_inpatient_bed_occupied_7_day_avg), if_float(total_icu_beds_7_day_avg), if_float(icu_beds_used_7_day_avg), if_float(inpatient_beds_used_covid_7_day_avg), if_float(staffed_icu_adult_patients_confirmed_covid_7_day_avg)))
        except Exception as e:
            # if ((all_adult_hospital_beds_7_day_avg < 0) or (all_adult_hospital_beds_7_day_avg == None)):
            #     print("all_adult_hospital_beds_7_day_avg failed")
            # elif (all_pediatric_inpatient_beds_7_day_avg < 0 or (all_pediatric_inpatient_beds_7_day_avg == None)):
            #     print("all_pediatric_inpatient_beds_7_day_avg failed")
            # elif (all_adult_hospital_inpatient_bed_occupied_7_day_coverage < 0 or (all_adult_hospital_inpatient_bed_occupied_7_day_coverage == None)):
            #     print("all_pediatric_inpatient_beds_7_day_avg failed")
            # elif (all_pediatric_inpatient_bed_occupied_7_day_avg < 0 or (all_pediatric_inpatient_bed_occupied_7_day_avg == None)):
            #     print("all_pediatric_inpatient_bed_occupied_7_day_avg")
            # elif (total_icu_beds_7_day_avg < 0) or (total_icu_beds_7_day_avg == None):
            #     print("total_icu_beds_7_day_avg")
            # elif (icu_beds_used_7_day_avg < 0) or (icu_beds_used_7_day_avg == None):
            #     print("icu_beds_used_7_day_avg")
            # elif (inpatient_beds_used_covid_7_day_avg <0) or (inpatient_beds_used_covid_7_day_avg == None):
            #     print("inpatient_beds_used_covid_7_day_avg")
            # else:
            #     print("staffed_icu_adult_patients_confirmed_covid_7_day_avg")
            print("Insert failed!", e)
            df3.loc[nrow]=df.iloc[row,[0,1,12,111,55,108,22,24,16,27]]
            nrow+=1
        else:
            num_rows_inserted_weekly += 1

print(nrow)
print(num_rows_inserted_weekly)
# Out:
# Insert failed! new row for relation "hospital_we2" violates check constraint "hospital_we2_all_pediatric_inpatient_beds_7_day_avg_check"
# DETAIL:  Failing row contains (1028, 111337, 2022-09-23, 30, -1, 7, 0, 0, 0, 0, 0).
# 1
# 4995

# %%
missing_values = [-999999, np.nan]
qf=pd.read_csv("CMS_data/Hospital_General_Information-2021-07.csv", na_values=missing_values)
qf.loc[qf["Hospital overall rating"]== "Not Available"]=None
qf["Hospital overall rating"]
# Out:
# 0          3
# 1          2
# 2          2
# 3          2
# 4          2
#         ...
# 5331    None
# 5332    None
# 5333    None
# 5334    None
# 5335    None
# Name: Hospital overall rating, Length: 5336, dtype: object

# %%
nrow2=0
df6=pd.DataFrame(columns=["facility_id, type_of_hospital, ownership, emergency, overall_quality_rating"])
num_rows_inserted_quality=0
with conn.transaction():
    for row in range(qf.shape[0]):
        facility_id = qf.iloc[row, 0]
        time = '2017-03-14'
        type_of_hospital = qf.iloc[row, 8]
        ownership = qf.iloc[row, 9]
        emergency = qf.iloc[row, 10]
        overall_quality_rating = qf.iloc[row, 12]
        try:
            with conn.transaction():
                cur.execute("insert into hospital_quali (facility_id, update_time, type_of_hospital, ownership, emergency, overall_quality_rating) values ( %s, %s, %s, %s, %s, %s) ON CONFLICT (hospital_pk) DO NOTHING ", (facility_id, time, type_of_hospital, ownership, emergency, if_float(overall_quality_rating)))
        except Exception as e:
            print("Insert failed!", e)
            df6.loc[nrow2]=df.iloc[row,[0,8,9,10,12]]
            nrow2+=1
        else:
            num_rows_inserted_quality += 1

print(nrow2)
print(num_rows_inserted_quality)
# Out:
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! float() argument must be a string or a number, not 'NoneType'
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# Insert failed! column "hospital_pk" does not exist
# LINE 1: ...ing) values ( $1, $2, $3, $4, $5, $6) ON CONFLICT (hospital_...
#                                                              ^
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/connection.py:911, in Connection.transaction(self, savepoint_name, force_rollback)
#     910 with tx:
# --> 911     yield tx
#
# /Users/hirengupta/Desktop/Fall 2022/Data Engineering/Project/Data-Engineering/try2.ipynb Cell 12 in <cell line: 4>()
#      <a href='vscode-notebook-cell:/Users/hirengupta/Desktop/Fall%202022/Data%20Engineering/Project/Data-Engineering/try2.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> try:
# ---> <a href='vscode-notebook-cell:/Users/hirengupta/Desktop/Fall%202022/Data%20Engineering/Project/Data-Engineering/try2.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a>     with conn.transaction():
#      <a href='vscode-notebook-cell:/Users/hirengupta/Desktop/Fall%202022/Data%20Engineering/Project/Data-Engineering/try2.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a>         cur.execute("insert into hospital_quali (facility_id, update_time, type_of_hospital, ownership, emergency, overall_quality_rating) values ( %s, %s, %s, %s, %s, %s) ON CONFLICT (hospital_pk) DO NOTHING ", (facility_id, time, type_of_hospital, ownership, emergency, if_float(overall_quality_rating)))
#
# File ~/opt/anaconda3/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/connection.py:910, in Connection.transaction(self, savepoint_name, force_rollback)
#     909 else:
# --> 910     with tx:
#     911         yield tx
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/transaction.py:246, in Transaction.__enter__(self)
#     245 with self._conn.lock:
# --> 246     self._conn.wait(self._enter_gen())
#     247 return self
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/connection.py:956, in Connection.wait(self, gen, timeout)
#     955 try:
# --> 956     return waiting.wait(gen, self.pgconn.socket, timeout=timeout)
#     957 except KeyboardInterrupt:
#     958     # On Ctrl-C, try to cancel the query in the server, otherwise
#     959     # the connection will remain stuck in ACTIVE state.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/waiting.py:57, in wait_selector(gen, fileno, timeout)
#      56 while not rlist:
# ---> 57     rlist = sel.select(timeout=timeout)
#      58 sel.unregister(fileno)
#
# File ~/opt/anaconda3/lib/python3.9/selectors.py:562, in KqueueSelector.select(self, timeout)
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# OutOfOrderTransactionNesting              Traceback (most recent call last)
# /Users/hirengupta/Desktop/Fall 2022/Data Engineering/Project/Data-Engineering/try2.ipynb Cell 12 in <cell line: 4>()
#      <a href='vscode-notebook-cell:/Users/hirengupta/Desktop/Fall%202022/Data%20Engineering/Project/Data-Engineering/try2.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a>             nrow2+=1
#      <a href='vscode-notebook-cell:/Users/hirengupta/Desktop/Fall%202022/Data%20Engineering/Project/Data-Engineering/try2.ipynb#X14sZmlsZQ%3D%3D?line=18'>19</a>         else:
# ---> <a href='vscode-notebook-cell:/Users/hirengupta/Desktop/Fall%202022/Data%20Engineering/Project/Data-Engineering/try2.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a>             num_rows_inserted_quality += 1
#      <a href='vscode-notebook-cell:/Users/hirengupta/Desktop/Fall%202022/Data%20Engineering/Project/Data-Engineering/try2.ipynb#X14sZmlsZQ%3D%3D?line=21'>22</a> print(nrow2)
#      <a href='vscode-notebook-cell:/Users/hirengupta/Desktop/Fall%202022/Data%20Engineering/Project/Data-Engineering/try2.ipynb#X14sZmlsZQ%3D%3D?line=22'>23</a> print(num_rows_inserted_quality)
#
# File ~/opt/anaconda3/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     135     value = typ()
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#     142     return exc is not value
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/connection.py:911, in Connection.transaction(self, savepoint_name, force_rollback)
#     909 else:
#     910     with tx:
# --> 911         yield tx
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/transaction.py:257, in Transaction.__exit__(self, exc_type, exc_val, exc_tb)
#     255 if self.pgconn.status == OK:
#     256     with self._conn.lock:
# --> 257         return self._conn.wait(self._exit_gen(exc_type, exc_val, exc_tb))
#     258 else:
#     259     return False
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/connection.py:956, in Connection.wait(self, gen, timeout)
#     949 """
#     950 Consume a generator operating on the connection.
#     951
#     952 The function must be used on generators that don't change connection
#     953 fd (i.e. not on connect and reset).
#     954 """
#     955 try:
# --> 956     return waiting.wait(gen, self.pgconn.socket, timeout=timeout)
#     957 except KeyboardInterrupt:
#     958     # On Ctrl-C, try to cancel the query in the server, otherwise
#     959     # the connection will remain stuck in ACTIVE state.
#     960     c = self.pgconn.get_cancel()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/waiting.py:51, in wait_selector(gen, fileno, timeout)
#      36 """
#      37 Wait for a generator using the best strategy available.
#      38
#    (...)
#      48 block. Once ready again send the ready state back to *gen*.
#      49 """
#      50 try:
# ---> 51     s = next(gen)
#      52     with DefaultSelector() as sel:
#      53         while True:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/transaction.py:113, in BaseTransaction._exit_gen(self, exc_type, exc_val, exc_tb)
#     109 else:
#     110     # try to rollback, but if there are problems (connection in a bad
#     111     # state) just warn without clobbering the exception bubbling up.
#     112     try:
# --> 113         return (yield from self._rollback_gen(exc_val))
#     114     except OutOfOrderTransactionNesting:
#     115         # Clobber an exception happened in the block with the exception
#     116         # caused by out-of-order transaction detected, so make the
#     117         # behaviour consistent with _commit_gen and to make sure the
#     118         # user fixes this condition, which is unrelated from
#     119         # operational error that might arise in the block.
#     120         raise
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/transaction.py:141, in BaseTransaction._rollback_gen(self, exc_val)
#     139 self._exited = True
#     140 if ex:
# --> 141     raise ex
#     143 for command in self._get_rollback_commands():
#     144     yield from self._conn._exec_command(command)
#
# OutOfOrderTransactionNesting: transaction rollback at the wrong nesting level: <psycopg.Transaction '_pg3_2' (active) [INTRANS] (host=sculptor.stat.cmu.edu database=hireng) at 0x7fe0c4b90ca0>
